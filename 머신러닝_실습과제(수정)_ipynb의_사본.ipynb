# %% [markdown]
# <a href="https://colab.research.google.com/github/2101100/-2101100-/blob/main/%EB%A8%B8%EC%8B%A0%EB%9F%AC%EB%8B%9D_%EC%8B%A4%EC%8A%B5%EA%B3%BC%EC%A0%9C(%EC%88%98%EC%A0%95)_ipynb%EC%9D%98_%EC%82%AC%EB%B3%B8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
with open("/content/drive/MyDrive/I_have_a_dream.txt",'r') as f:
  lines=f.readlines()

  wordCounts={}
  line_lower=[]

  for line in lines:
    line_lower.append(line.lower())
    line_one=' '.join(line_lower)

    line_one = line_one.replace(',','')
    line_one = line_one.replace('.','')
    line_one = line_one.replace('"','')
    line_one = line_one.replace('?','')
    line_one = line_one.replace('!','')
    line_one = line_one.replace('*','')

    words=line_one.split()
  for word in words:
    if word in wordCounts:
      wordCounts[word]+=1
    else:
      wordCounts[word]=1

wordCounts_1=dict(sorted(wordCounts.items()))
print(wordCounts_1)

import pandas as pd
pd.set_option('display.max_row', 500)
pd.Series(wordCounts_1)
# Out:
# {'a': 22, 'again': 2, 'ago': 1, 'ahead': 1, 'all': 3, 'allow': 1, 'alone': 1, 'also': 1, 'always': 1, 'am': 1, 'america': 4, 'american': 3, 'an': 3, 'and': 22, 'architects': 1, 'are': 6, 'as': 19, 'asking': 1, 'autumn': 1, 'awakening': 1, 'back': 2, 'bad': 1, 'bank': 1, 'bankrupt': 1, 'basic': 1, 'be': 12, 'beacon': 1, 'been': 1, 'beginning': 1, 'believe': 2, 'believes': 1, 'bitterness': 1, 'black': 1, 'blow': 1, 'bodies': 1, 'bound': 1, 'bright': 1, 'brotherhood': 1, 'brothers': 1, 'brutality': 1, 'business': 1, 'but': 4, 'by': 4, 'came': 2, 'can': 3, 'cannot': 6, 'capital': 1, 'captivity': 1, 'cash': 2, 'chains': 1, 'check': 5, 'children': 2, 'cities': 1, 'citizens': 1, 'citizenship': 1, 'civil': 1, 'color': 1, 'come': 7, 'community': 1, 'concerned': 1, 'condition': 1, 'conduct': 1, 'constitution': 1, 'content': 1, 'continue': 1, 'cooling': 1, 'corners': 1, 'creative': 1, 'crippled': 1, 'cup': 1, 'dark': 1, 'day': 1, 'daybreak': 1, 'declaration': 1, 'decree': 1, 'deeds': 1, 'defaul
# ...
